# %% [markdown]
# ### Linear Regression

# %% [markdown]
# Linear Equation
#
# y = b0 + b1*x where b0 and b1 reperent the intercept and slope.

# %% [markdown]
# Measuring the coefficient. Least Square approach.
# RSS - Residual sun of square.
# Residual is the difference between y - y (observed vs predicted)

# %% [markdown]
# Assessing the accuracy of the coefficient estimate.
# True relationship between X and Y =: y = f(X) + e where e is mean zero random error term.

# %%
# Import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
rng = np.random.default_rng()

x = rng.random(100)
# x = rng.normal(size = (100))
# y = rng.normal(size = (100))
e = rng.normal(size = (100))

# %%
x
# Out:
# array([0.89173985, 0.01526229, 0.96709376, 0.83931785, 0.02897258,
#        0.47822241, 0.18032232, 0.16058214, 0.94091128, 0.9925121 ,
#        0.73153818, 0.64480822, 0.86989271, 0.46765836, 0.35408884,
#        0.83686365, 0.3805583 , 0.55013747, 0.67190545, 0.14008768,
#        0.17378999, 0.2527697 , 0.9407109 , 0.92718119, 0.60804967,
#        0.44290208, 0.39993758, 0.36875345, 0.15157292, 0.21862283,
#        0.2530722 , 0.68828909, 0.43017246, 0.36103018, 0.16660982,
#        0.51205014, 0.78936319, 0.98728594, 0.08153999, 0.59488485,
#        0.46654242, 0.39115313, 0.23549748, 0.96869939, 0.52143521,
#        0.02669352, 0.92121202, 0.20212263, 0.70061408, 0.07936747,
#        0.21839964, 0.26826184, 0.89391201, 0.58269626, 0.99547748,
#        0.05516179, 0.83070652, 0.0242111 , 0.30482257, 0.22969955,
#        0.55700799, 0.27728669, 0.02347006, 0.61768327, 0.59802308,
#        0.25040626, 0.84270709, 0.27829528, 0.31178176, 0.03196029,
#        0.18098433, 0.83497525, 0.92643926, 0.87591858, 0.94323136,
#        0.80516126, 0.47956064, 0.3263    , 0.47547862, 0.26098492,
#        0.28595431, 0.57047706, 0.05860098, 0.89124352, 0.6997103 ,
#        0.20274893, 0.87710092, 0.49179004, 0.94288382, 0.94892484,
#        0.86850683, 0.91332579, 0.71775193, 0.56572903, 0.88340424,
#        0.44289675, 0.11012014, 0.23929659, 0.23670456, 0.16477595])

# %%
y = 2 + 3*x + e
y
# Out:
# array([5.28725212, 0.35457209, 4.1705837 , 4.132213  , 1.67181813,
#        3.22811705, 2.73112793, 1.77176782, 3.67768452, 4.60112317,
#        2.97523914, 4.66952724, 5.26327777, 5.55579548, 3.0277932 ,
#        5.38074958, 4.18887839, 0.10765284, 3.21001304, 2.39536472,
#        1.85904551, 2.90215903, 6.57354422, 4.74196676, 5.07146241,
#        2.89602059, 2.60862265, 4.12826231, 2.62438059, 0.79315987,
#        2.67393419, 5.54837454, 2.68225648, 4.71272944, 3.33948454,
#        3.71936528, 2.26972736, 4.91574853, 1.589205  , 2.12126612,
#        4.5689224 , 3.93959239, 4.26164272, 4.47203143, 2.33891895,
#        2.84114123, 3.92740105, 1.48964398, 3.98661598, 2.10519068,
#        1.57415193, 3.35196011, 7.15051665, 4.125609  , 4.47322418,
#        0.78406055, 4.41337895, 3.39221291, 4.7027134 , 3.15267901,
#        4.74397675, 2.62026588, 2.61635336, 4.31465184, 2.83850065,
#        2.29322323, 3.41308626, 3.3984333 , 2.2954853 , 2.14825687,
#        3.38656565, 5.89730176, 4.96076914, 4.71886453, 5.07859175,
#        4.10208082, 3.13087389, 2.02264042, 3.98878949, 4.21336183,
#        2.02691983, 4.2810179 , 0.59568447, 3.4445587 , 1.77117335,
#        4.11752911, 2.96564194, 3.41693627, 4.49241845, 4.08707313,
#        3.01488905, 4.52011068, 4.40307923, 3.30751931, 4.52988704,
#        3.78580654, 2.21134516, 3.65458364, 3.54600143, 2.6710353 ])

# %%
plt.hist(y)
# Out:
# (array([ 5.,  1., 12., 17., 18., 20., 17.,  7.,  1.,  2.]),
#  array([0.10765284, 0.81193922, 1.5162256 , 2.22051198, 2.92479836,
#         3.62908474, 4.33337112, 5.0376575 , 5.74194388, 6.44623027,
#         7.15051665]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(x)

# %%
plt.plot(y)

# %%
plt.plot(x,y,)

# %%
plt.scatter(x,y)

# %%
plt 2 lines
